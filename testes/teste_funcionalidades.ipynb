# %%
import pandas as pd 
from faker import Faker
from datetime import date
import random

# %%
name = "Joao oliveira"
name.replace(" ","-")
# Out:
# 'Joao-oliveira'

# %%
class Setter: 
    def __init__(self):
        self.fake = Faker('pt-BR')

    def Pessoa(self):
        name = self.fake.first_name()  # Nome próprio
        last_name = self.fake.last_name()  # Sobrenome
        email = self.fake.email()  # E-mail
        phone_number = self.fake.phone_number()  # Número de telefone
        state = self.fake.state()  # Estado
        city = self.fake.city()  # "São Paulo"
        birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)  # Idade entre 18 e 80 anos 
        birth_formated = birth.strftime('%d/%m/%Y')
        today = date.today()
        age = today.year - birth.year - ((today.month, today.day) < (birth.month, birth.day))
        
        return (name,last_name,email,phone_number,state,city,birth_formated,age)

# %%
# Classe Setter com as classes internas Pessoa e Usuario
class Setter:
    def __init__(self):
        self.fake = Faker('pt-BR')
    
    # Classe Pessoa que contém os dados comuns a todas as pessoas
    class Pessoa:
        def __init__(self, fake):
            self.fake = fake
            self.name = self.fake.first_name()  # Nome próprio
            self.last_name = self.fake.last_name()  # Sobrenome
            self.email = self.fake.email()  # E-mail
            self.phone_number = self.fake.phone_number()  # Número de telefone
            self.state = self.fake.state()  # Estado
            self.city = self.fake.city()  # Cidade
            self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)  # Idade entre 18 e 80 anos
            self.age = self.calculate_age()

        # Método para calcular a idade
        def calculate_age(self):
            today = date.today()
            return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

        def exibir_valores(self):
            print(f"Nome: {self.name} {self.last_name}"),
            print(f"E-mail: {self.email}"),
            print(f"Telefone {self.phone_number}"),
            print(f"Estado {self.state}"),
            print(f"Cidade {self.city}"),
            print(f"Data de Nascimento {self.birth_formated}"),
            print(f"Idade {self.age}")

    # Classe Usuario que herda de Pessoa
    class Usuario(Pessoa):
        def __init__(self, fake):
            super().__init__(fake)  # Chama o construtor da classe base Pessoa
            self.username = self.fake.user_name()  # Nome de usuário

# %%
# Exemplo de uso
setter = Setter()

# Instanciar a classe Pessoa a partir do Setter
pessoa = setter.Pessoa(setter.fake)

# Chamar o método para exibir os dados
pessoa.exibir_valores()
# Out:
# Nome: Caio Silva
# E-mail: britostephany@example.com
# Telefone +55 61 8783-1925
# Estado Paraná
# Cidade Costela do Amparo
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[174], line 8
#       5 pessoa = setter.Pessoa(setter.fake)
#       7 # Chamar o método para exibir os dados
# ----> 8 pessoa.exibir_valores()
#
# Cell In[172], line 30, in Setter.Pessoa.exibir_valores(self)
#      28 print(f"Estado {self.state}"),
#      29 print(f"Cidade {self.city}"),
# ---> 30 print(f"Data de Nascimento {self.birth_formated}"),
#      31 print(f"Idade {self.age}")
#
# AttributeError: 'Pessoa' object has no attribute 'birth_formated'

# %%
# Classe Pessoa que contém os dados comuns a todas as pessoas
class SetPessoa:
    def __init__(self):
        self.fake = Faker('pt-BR')
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

    # Método para calcular a idade
    def calculate_age(self):
        today = date.today()
        return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

    def exibir_valores(self):
        print(f"Nome: {self.name} {self.last_name}"),
        print(f"E-mail: {self.email}"),
        print(f"Telefone: {self.phone_number}"),
        print(f"Estado: {self.state}"),
        print(f"Cidade: {self.city}"),
        print(f"Data de Nascimento: {self.birth_formated}"),
        print(f"Idade: {self.age}")

    def get_data(self):
        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }
        return data
        
class SetUsuario(SetPessoa):
    def __init__(self):
        super().__init__()  # Chama o construtor da classe base SetPessoa
        self.username = (f"{self.name.lower()}-{self.last_name.lower()}").replace(" ","_") # Nome de usuário gerado aleatoriamente

    # Método para exibir os dados da classe Usuario
    def exibir_valores(self):
        super().exibir_valores()  # Chama a exibição dos dados da classe base
        print(f"Username: {self.username}")  # Exibe o nome de usuário
    

def gerar_dataset(object, num_registros):
    dados = []
    for _ in range(num_registros):
        ob = object()
        dados.append(ob.get_data())
    
    df = pd.DataFrame(dados)
    return df

# %%
pessoa = SetPessoa()


dataframe = gerar_dataset(pessoa,100)

dataframe
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[198], line 4
#       1 pessoa = SetPessoa()
# ----> 4 dataframe = gerar_dataset(pessoa,100)
#       6 dataframe
#
# Cell In[196], line 56, in gerar_dataset(object, num_registros)
#      54 dados = []
#      55 for _ in range(num_registros):
# ---> 56     ob = object()
#      57     dados.append(ob.get_data())
#      59 df = pd.DataFrame(dados)
#
# TypeError: 'SetPessoa' object is not callable

# %%
dataframe
# Out:
#        name last_name   phone_number             state               city  \
# 0   Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 1   Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 2   Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 3   Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 4   Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# ..      ...       ...            ...               ...                ...
# 95  Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 96  Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 97  Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 98  Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
# 99  Heloisa     Brito  0800-279-6855  Distrito Federal  Cardoso de Câmara
#
#          birth  age                    email
# 0   25/08/1986   38  heloisa.brito@gmail.com
# 1   25/08/1986   38  heloisa.brito@gmail.com
# 2   25/08/1986   38  heloisa.brito@gmail.com
# 3   25/08/1986   38  heloisa.brito@gmail.com
# 4   25/08/1986   38  heloisa.brito@gmail.com
# ..         ...  ...                      ...
# 95  25/08/1986   38  heloisa.brito@gmail.com
# 96  25/08/1986   38  heloisa.brito@gmail.com
# 97  25/08/1986   38  heloisa.brito@gmail.com
# 98  25/08/1986   38  heloisa.brito@gmail.com
# 99  25/08/1986   38  heloisa.brito@gmail.com
#
# [100 rows x 8 columns]

# %%
usuario = SetUsuario()

usuario.exibir_valores()
# Out:
# Nome: André Gonçalves
# E-mail: andré.gonçalves@hotmail.com
# Telefone: 81 4964-7620
# Estado: Rio Grande do Norte
# Cidade: Oliveira
# Data de Nascimento: 31/07/1951
# Idade: 73
# Username: andré-gonçalves

# %%
print("\nAtributos da classe Usuario:")
for chave, valor in pessoa.get().items():
    print(f"{chave}: {valor}")
# Out:
# Atributos da classe Usuario:
# fake: <faker.proxy.Faker object at 0x0000026C284C8E90>
# name: Bento
# last_name: Cunha
# phone_number: (041) 1062-2728
# state: Sergipe
# city: Cavalcanti
# birth: 1995-09-18
# age: 29
# email: bento.cunha@outlook.com

# %%
class SetPessoa:
    def __init__(self):
        self.fake = Faker('pt-BR')
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

    # Método para calcular a idade
    def calculate_age(self):
        today = date.today()
        return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

    def create_data(self,qtd):
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
            
        return datas
    
    def get_data(self):
        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }
        return data


# Função para gerar o dataset
def gerar_dataset(object, num_registros):
    dados = []
    for _ in range(num_registros):
        ob = object()
        dados.append(ob.get_data())
    
    df = pd.DataFrame(dados)
    return df

# %%
dado = gerar_dataset(SetPessoa,10)

# %%
# Classe SetPessoa que contém os dados comuns a todas as pessoas
class SetPessoa:
    def __init__(self):
        self.fake = Faker('pt-BR')
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

    # Método para calcular a idade
    def calculate_age(self):
        today = date.today()
        return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

    # Método que retorna todos os dados
    def get_data(self):
        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }
        return data

# Função para gerar o dataset
def gerar_dataset(classe, num_registros):
    dados = []
    for _ in range(num_registros):
        obj = classe()  
        dados.append(obj.get_data()) 
    df = pd.DataFrame(dados)
    return df

# Gerando um dataset com 10 registros
dado = gerar_dataset(SetPessoa, 10)
# Out:
#           name  last_name         phone_number               state  \
# 0    Valentina     Fogaça         61 4779-0363                Pará
# 1      Kamilly    Marques         41 2819 0432      Espírito Santo
# 2         Otto       Rios         31 2322-7145               Bahia
# 3          Liz    Sampaio  +55 (041) 3573 9412      Santa Catarina
# 4        Asafe   Nogueira      (011) 0340-3143            Rondônia
# 5          Ana      Jesus         21 3817-5831               Ceará
# 6  Maria Luiza   Cassiano      (041) 2593 6473  Mato Grosso do Sul
# 7        Aylla      Sousa     +55 84 4719 9172  Mato Grosso do Sul
# 8        Luigi  Gonçalves     +55 31 3571-3246           São Paulo
# 9      Hellena   Oliveira         41 7879-4453             Paraíba
#
#                   city       birth  age                             email
# 0                   Sá  03/07/1955   69      valentina.fogaça@hotmail.com
# 1                Lopes  12/04/1950   74       kamilly.marques@hotmail.com
# 2               Barros  23/04/1957   67             otto.rios@hotmail.com
# 3               Novaes  16/12/1986   38           liz.sampaio@outlook.com
# 4     Lima de Teixeira  19/05/1965   59        asafe.nogueira@outlook.com
# 5  Viana de Cavalcanti  20/02/1987   38               ana.jesus@gmail.com
# 6       Jesus de Goiás  27/12/1953   71  maria-luiza.cassiano@hotmail.com
# 7              Cardoso  18/02/1964   61           aylla.sousa@hotmail.com
# 8              Almeida  05/09/1993   31       luigi.gonçalves@hotmail.com
# 9                   Sá  08/07/1978   46      hellena.oliveira@outlook.com

# %%
dado
# Out:
#           name  last_name         phone_number               state  \
# 0    Valentina     Fogaça         61 4779-0363                Pará
# 1      Kamilly    Marques         41 2819 0432      Espírito Santo
# 2         Otto       Rios         31 2322-7145               Bahia
# 3          Liz    Sampaio  +55 (041) 3573 9412      Santa Catarina
# 4        Asafe   Nogueira      (011) 0340-3143            Rondônia
# 5          Ana      Jesus         21 3817-5831               Ceará
# 6  Maria Luiza   Cassiano      (041) 2593 6473  Mato Grosso do Sul
# 7        Aylla      Sousa     +55 84 4719 9172  Mato Grosso do Sul
# 8        Luigi  Gonçalves     +55 31 3571-3246           São Paulo
# 9      Hellena   Oliveira         41 7879-4453             Paraíba
#
#                   city       birth  age                             email
# 0                   Sá  03/07/1955   69      valentina.fogaça@hotmail.com
# 1                Lopes  12/04/1950   74       kamilly.marques@hotmail.com
# 2               Barros  23/04/1957   67             otto.rios@hotmail.com
# 3               Novaes  16/12/1986   38           liz.sampaio@outlook.com
# 4     Lima de Teixeira  19/05/1965   59        asafe.nogueira@outlook.com
# 5  Viana de Cavalcanti  20/02/1987   38               ana.jesus@gmail.com
# 6       Jesus de Goiás  27/12/1953   71  maria-luiza.cassiano@hotmail.com
# 7              Cardoso  18/02/1964   61           aylla.sousa@hotmail.com
# 8              Almeida  05/09/1993   31       luigi.gonçalves@hotmail.com
# 9                   Sá  08/07/1978   46      hellena.oliveira@outlook.com

# %%
from faker import Faker
import pandas as pd

class Pessoa:
    def __init__(self):
        self.fake = Faker()

    def gerar_nome(self):
        return self.fake.name()

    def gerar_idade(self):
        return self.fake.random_int(min=18, max=99)

    def gerar_endereco(self):
        return self.fake.address()

    def gerar_email(self):
        return self.fake.email()

    def gerar_dados_pessoa(self):
        return {
            'Nome': self.gerar_nome(),
            'Idade': self.gerar_idade(),
            'Endereço': self.gerar_endereco(),
            'Email': self.gerar_email()
        }

class Produto:
    def __init__(self):
        self.fake = Faker()

    def gerar_nome(self):
        return self.fake.word()

    def gerar_preco(self):
        return round(self.fake.random_number(digits=3), 2)

    def gerar_categoria(self):
        categorias = ['Eletrônicos', 'Roupas', 'Alimentos', 'Móveis', 'Brinquedos']
        return self.fake.random_element(elements=categorias)

    def gerar_dados_produto(self):
        return {
            'Nome': self.gerar_nome(),
            'Preço': self.gerar_preco(),
            'Categoria': self.gerar_categoria()
        }

def gerar_dataset(gerador_funcao, num_registros):
    dados = []
    for _ in range(num_registros):
        dados.append(gerador_funcao())
    
    df = pd.DataFrame(dados)
    return df

# Exemplo de uso
pessoa = Pessoa()
dataset_pessoas = gerar_dataset(pessoa.gerar_dados_pessoa, 10)
print("Dataset Pessoas:")
print(dataset_pessoas)

produto = Produto()
dataset_produtos = gerar_dataset(produto.gerar_dados_produto, 10)
print("\nDataset Produtos:")
print(dataset_produtos)
# Out:
# Dataset Pessoas:
#               Nome  Idade                                           Endereço  \
# 0      Daniel Odom     79  4242 Rivera Ramp Apt. 853\nPatriciaborough, MN...
# 1  Melinda Griffin     56  0156 Nguyen River Suite 333\nNorth Danielview,...
# 2      Leslie Ross     76                        USNV Gonzales\nFPO AP 80832
# 3    Curtis Fuller     51  2585 Gwendolyn Knoll Apt. 222\nPort Stephanie,...
# 4      Brenda Long     94        42718 Rivera Mountains\nAudreyton, AS 83723
# 5   Dana Middleton     55  53867 Patrick Village Apt. 688\nNew Lori, ND 4...
# 6   Tonya Sullivan     79   5479 Jeremy Lodge Apt. 966\nAshleyfurt, TN 22490
# 7     Erik Freeman     51             959 Erica Glen\nNorth Amanda, HI 13965
# 8  Matthew Johnson     63           96611 Guy Vista\nCampbellville, CO 97734
# 9   Gary Rodriguez     67                   PSC 7426, Box 0067\nAPO AE 40753
#
#                         Email
# 0       penasusan@example.org
# 1  pollardtiffany@example.com
# 2         donna11@example.org
# 3      longrachel@example.net
# 4        taylor08@example.org
# 5          ismith@example.com
# 6  carrillorhonda@example.com
# 7        adamware@example.org
# 8    alvarezkaren@example.net
# 9     whiterodney@example.net
#
# Dataset Produtos:
#        Nome  Preço    Categoria
# 0     least    117   Brinquedos
# 1    simple    838  Eletrônicos
# 2   tonight    274   Brinquedos
# 3  activity    612   Brinquedos
# 4        TV    923    Alimentos
# 5   receive    183       Móveis
# 6  hospital    507  Eletrônicos
# 7        so    357   Brinquedos
# 8      dark     71    Alimentos
# 9        TV    842    Alimentos

# %%
from datetime import date
import random
import pandas as pd

class SetPessoa:
    def __init__(self):
        self.fake = Faker('pt-BR')
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

    # Método para calcular a idade
    def calculate_age(self):
        today = date.today()
        return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

    def gerar_dados(self):
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }

        return data

    # Método que retorna todos os dados
    def get_data(self):
        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }
        return data

# Função para gerar o dataset
        def gerar_dataset(classe, num_registros):
            dados = []
            for _ in range(num_registros):
                dados.append(classe) 
            df = pd.DataFrame(dados)
            return df

pessoa = SetPessoa()

df = gerar_dataset(pessoa.gerar_dados(),10)

# %%
from datetime import date
import random
from faker import Faker
import pandas as pd

class SetPessoa:
    def __init__(self):
        self.fake = Faker('pt-BR')
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

    # Método para calcular a idade
    def calculate_age(self):
        today = date.today()
        return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

    # Método para gerar dados aleatórios
    def gerar_dados(self):
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

        # Retornando os dados em formato de dicionário
        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }
        return data

# Função para gerar o dataset
def gerar_dataset(classe, num_registros):
    dados = []
    for _ in range(num_registros):
        dados.append(classe.gerar_dados())  # Chama o método gerar_dados para cada instância
    df = pd.DataFrame(dados)
    return df

# Criando instância de SetPessoa
pessoa = SetPessoa()

# Gerando o dataset com 10 registros
df = gerar_dataset(pessoa, 10)

# Exibindo o dataset
df
# Out:
#           name last_name         phone_number              state  \
# 0         Ísis      Rios  +55 (061) 2929-6545              Bahia
# 1          Dom     Rocha      (051) 5152-1117          São Paulo
# 2      Manuela     Sousa         71 4514-2688              Ceará
# 3        Dante   Fonseca     +55 71 7325-2996  Rio Grande do Sul
# 4       Camila     Viana     +55 31 1109 0857           Rondônia
# 5  Ana Beatriz   Cardoso        0800 131 0193            Sergipe
# 6      Bárbara    Santos     +55 41 5861 5143         Pernambuco
# 7     Valentim    Araújo     +55 81 5951-3727              Amapá
# 8      Antônio  Nogueira         71 1570 0255              Goiás
# 9     Stephany   Peixoto     +55 31 0536-1863               Pará
#
#                     city       birth  age                            email
# 0                 Vieira  07/06/1981   43            ísis.rios@hotmail.com
# 1               Silveira  18/11/1958   66            dom.rocha@hotmail.com
# 2        Lima das Flores  10/01/1946   79        manuela.sousa@hotmail.com
# 3                da Mata  26/11/1976   48        dante.fonseca@outlook.com
# 4                   Lima  21/01/1976   49         camila.viana@hotmail.com
# 5                Moreira  23/10/1991   33  ana-beatriz.cardoso@hotmail.com
# 6  Fonseca de Cavalcanti  18/11/1967   57       bárbara.santos@outlook.com
# 7                 Macedo  11/06/1957   67      valentim.araújo@hotmail.com
# 8     Porto dos Dourados  02/02/2000   25     antônio.nogueira@outlook.com
# 9        Moraes de Goiás  10/01/2003   22       stephany.peixoto@gmail.com

# %%
from datetime import date
import random
from faker import Faker
import pandas as pd

class SetPessoa:
    def __init__(self):
        self.fake = Faker('pt-BR')
        self.name = self.fake.first_name()  # Nome próprio
        self.last_name = self.fake.last_name()  # Sobrenome
        self.phone_number = self.fake.phone_number()  # Número de telefone
        self.state = self.fake.state()  # Estado
        self.city = self.fake.city()  # Cidade 
        self.birth = self.fake.date_of_birth(minimum_age=18, maximum_age=80)
        self.age = self.calculate_age()
        domains = ['gmail.com', 'outlook.com', 'hotmail.com']
        self.email = (f"{self.name.lower()}.{self.last_name.lower()}@{random.choice(domains)}").replace(" ","-")

    # Método para calcular a idade
    def calculate_age(self):
        today = date.today()
        return today.year - self.birth.year - ((today.month, today.day) < (self.birth.month, self.birth.day))

    # Método para gerar dados aleatórios (usando os atributos já definidos)
    def gerar_dados(self):
        # Retornando os dados diretamente dos atributos da classe
        data = {
            "name": self.name,
            "last_name": self.last_name,
            "phone_number": self.phone_number,
            "state": self.state,
            "city": self.city,
            "birth": self.birth.strftime('%d/%m/%Y'),
            "age": self.age,
            "email": self.email
        }
        return data

# Função para gerar o dataset
def gerar_dataset(classe, num_registros):
    dados = []
    for _ in range(num_registros):
        op = classe()
        dados.append(op.gerar_dados())  # Chama o método gerar_dados para cada instância
    df = pd.DataFrame(dados)
    return df

# Criando instância de SetPessoa
pessoa = SetPessoa

# Gerando o dataset com 10 registros
df = gerar_dataset(pessoa, 10)

# Exibindo o dataset
print(df)
# Out:
#           name  last_name         phone_number         state  \
# 0     Leonardo     Duarte      (071) 6025 2424         Bahia
# 1      Hellena   Caldeira  +55 (041) 5503 2538         Bahia
# 2        Luigi  das Neves  +55 (061) 4655-6968    Pernambuco
# 3      Gabriel    Moreira         41 4016 1334      Maranhão
# 4  Maria Alice    Azevedo      (011) 7962-9943      Amazonas
# 5       Milena    Marques     +55 61 0120-9575       Roraima
# 6     Henrique     Aragão         31 1961 8224         Piauí
# 7       Marina  das Neves        0900-109-5874     Tocantins
# 8        Maria    Pacheco         84 4752-0519  Minas Gerais
# 9     Leonardo    da Rosa  +55 (021) 0544-4573       Alagoas
#
#                     city       birth  age                            email
# 0     Duarte de Cassiano  25/11/2001   23      leonardo.duarte@hotmail.com
# 1                da Mata  21/04/2002   22       hellena.caldeira@gmail.com
# 2      Leão dos Dourados  17/04/1977   47      luigi.das-neves@outlook.com
# 3        Oliveira do Sul  04/04/1975   49      gabriel.moreira@hotmail.com
# 4                 Guerra  24/10/2000   24  maria-alice.azevedo@hotmail.com
# 5               Caldeira  05/12/1971   53       milena.marques@hotmail.com
# 6            Albuquerque  26/07/1948   76        henrique.aragão@gmail.com
# 7  Montenegro das Pedras  10/06/1993   31     marina.das-neves@hotmail.com
# 8                  Souza  19/03/1993   31          maria.pacheco@gmail.com
# 9     Gomes dos Dourados  13/10/1970   54     leonardo.da-rosa@hotmail.com
